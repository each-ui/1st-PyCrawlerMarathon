# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11419101088","type":"PushEvent","actor":{"id":14127285,"login":"funilrys","display_login":"funilrys","gravatar_id":"","url":"https://api.github.com/users/funilrys","avatar_url":"https://avatars.githubusercontent.com/u/14127285?"},"repo":{"id":124745072,"name":"Ultimate-Hosts-Blacklist/Airelles_Anti_Sex_Hosts","url":"https://api.github.com/repos/Ultimate-Hosts-Blacklist/Airelles_Anti_Sex_Hosts"},"payload":{"push_id":4578211822,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"b9f545395c2d424b6a4bcdb143977d39d447bc13","before":"468993c99a1dc8123606096f93a32cdf6caa53f8","commits":[{"sha":"b9f545395c2d424b6a4bcdb143977d39d447bc13","author":{"email":"contact@funilrys.com","name":"Nissar Chababy"},"message":"[MON] [Restart last part]","distinct":true,"url":"https://api.github.com/repos/Ultimate-Hosts-Blacklist/Airelles_Anti_Sex_Hosts/commits/b9f545395c2d424b6a4bcdb143977d39d447bc13"}]},"public":true,"created_at":"2020-02-03T07:00:52Z","org":{"id":37181187,"login":"Ultimate-Hosts-Blacklist","gravatar_id":"","url":"https://api.github.com/orgs/Ultimate-Hosts-Blacklist","avatar_url":"https://avatars.githubusercontent.com/u/37181187?"}},{"id":"11419101087","type":"PushEvent","actor":{"id":1311012,"login":"cgspeck","display_login":"cgspeck","gravatar_id":"","url":"https://api.github.com/users/cgspeck","avatar_url":"https://avatars.githubusercontent.com/u/1311012?"},"repo":{"id":236698391,"name":"cgspeck/barndoor-tracker-pi","url":"https://api.github.com/repos/cgspeck/barndoor-tracker-pi"},"payload":{"push_id":4578211820,"size":2,"distinct_size":2,"ref":"refs/heads/master","head":"ca949bd923b384eb84f061f1efec120fdaf40872","before":"c5ac7e8d5568a36095097a468369aedae567a419","commits":[{"sha":"60779ea63a081e23f606952e3026235b7e81f2da","author":{"email":"cgspeck@gmail.com","name":"Chris Speck"},"message":"Update gitignore","distinct":true,"url":"https://api.github.com/repos/cgspeck/barndoor-tracker-pi/commits/60779ea63a081e23f606952e3026235b7e81f2da"},{"sha":"ca949bd923b384eb84f061f1efec120fdaf40872","author":{"email":"cgspeck@gmail.com","name":"Chris Speck"},"message":"More tests, and writing of config","distinct":true,"url":"https://api.github.com/repos/cgspeck/barndoor-tracker-pi/commits/ca949bd923b384eb84f061f1efec120fdaf40872"}]},"public":true,"created_at":"2020-02-03T07:00:52Z"},{"id":"11419101082","type":"CreateEvent","actor":{"id":26675745,"login":"jerrylee17","display_login":"jerrylee17","gravatar_id":"","url":"https://api.github.com/users/jerrylee17","avatar_url":"https://avatars.githubusercontent.com/u/26675745?"},"repo":{"id":99932533,"name":"SCE-Development/Core-v4","url":"https://api.github.com/repos/SCE-Development/Core-v4"},"payload":{"ref":"jerry/travis","ref_type":"branch","master_branch":"dev","description":"Made entirely by SJSU students, this is the Software and Computer Engineering Society\'s outward face on the internet.","pusher_type":"user"},"public":true,"created_at":"2020-02-03T07:00:52Z","org":{"id":17789654,"login":"SCE-Development","gravatar_id":"","url":"https://api.github.com/orgs/SCE-Development","avatar_url":"https://avatars.githubusercontent.com/u/17789654?"}},{"id":"11419101081","type":"IssueCommentEvent","actor":{"id":157375,"login":"danada","display_login":"danada","gravatar_id":"","url":"https://api.github.com/users/danada","avatar_url":"https://avatars.githubusercontent.com/u/157375?"},"repo":{"id":83122389,"name":"curioswitch/curiostack","url":"https://api.github.com/repos/curioswitch/curiostack"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/curioswitch/curiostack/issues/509","repository_url":"https://api.github.com/repos/curioswitch/curiostack","labels_url":"https://api.github.com/repos/curioswitch/curiostack/issues/509/labels{/name}","comments_url":"https://api.github.com/repos/curioswitch/curiostack/issues/509/comments","events_url":"https://api.github.com/repos/curioswitch/curiostack/issues/509/events","html_url":"https://github.com/curioswitch/curi ...

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '11419101088',
#   'type': 'PushEvent',
#   'actor': {'id': 14127285,
#    'login': 'funilrys',
#    'display_login': 'funilrys',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/funilrys',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14127285?'},
#   'repo': {'id': 124745072,
#    'name': 'Ultimate-Hosts-Blacklist/Airelles_Anti_Sex_Hosts',
#    'url': 'https://api.github.com/repos/Ultimate-Hosts-Blacklist/Airelles_Anti_Sex_Hosts'},
#   'payload': {'push_id': 4578211822,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b9f545395c2d424b6a4bcdb143977d39d447bc13',
#    'before': '468993c99a1dc8123606096f93a32cdf6caa53f8',
#    'commits': [{'sha': 'b9f545395c2d424b6a4bcdb143977d39d447bc13',
#      'author': {'email': 'contact@funilrys.com', 'name': 'Nissar Chababy'},
#      'message': '[MON] [Restart last part]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ultimate-Hosts-Blacklist/Airelles_Anti_Sex_Hosts/commits/b9f545395c2d424b6a4bcdb143977d39d447bc13'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z',
#   'org': {'id': 37181187,
#    'login': 'Ultimate-Hosts-Blacklist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Ultimate-Hosts-Blacklist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37181187?'}},
#  {'id': '11419101087',
#   'type': 'PushEvent',
#   'actor': {'id': 1311012,
#    'login': 'cgspeck',
#    'display_login': 'cgspeck',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cgspeck',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1311012?'},
#   'repo': {'id': 236698391,
#    'name': 'cgspeck/barndoor-tracker-pi',
#    'url': 'https://api.github.com/repos/cgspeck/barndoor-tracker-pi'},
#   'payload': {'push_id': 4578211820,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'ca949bd923b384eb84f061f1efec120fdaf40872',
#    'before': 'c5ac7e8d5568a36095097a468369aedae567a419',
#    'commits': [{'sha': '60779ea63a081e23f606952e3026235b7e81f2da',
#      'author': {'email': 'cgspeck@gmail.com', 'name': 'Chris Speck'},
#      'message': 'Update gitignore',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cgspeck/barndoor-tracker-pi/commits/60779ea63a081e23f606952e3026235b7e81f2da'},
#     {'sha': 'ca949bd923b384eb84f061f1efec120fdaf40872',
#      'author': {'email': 'cgspeck@gmail.com', 'name': 'Chris Speck'},
#      'message': 'More tests, and writing of config',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cgspeck/barndoor-tracker-pi/commits/ca949bd923b384eb84f061f1efec120fdaf40872'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101082',
#   'type': 'CreateEvent',
#   'actor': {'id': 26675745,
#    'login': 'jerrylee17',
#    'display_login': 'jerrylee17',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jerrylee17',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26675745?'},
#   'repo': {'id': 99932533,
#    'name': 'SCE-Development/Core-v4',
#    'url': 'https://api.github.com/repos/SCE-Development/Core-v4'},
#   'payload': {'ref': 'jerry/travis',
#    'ref_type': 'branch',
#    'master_branch': 'dev',
#    'description': "Made entirely by SJSU students, this is the Software and Computer Engineering Society's outward face on the internet.",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z',
#   'org': {'id': 17789654,
#    'login': 'SCE-Development',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SCE-Development',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17789654?'}},
#  {'id': '11419101081',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 157375,
#    'login': 'danada',
#    'display_login': 'danada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157375?'},
#   'repo': {'id': 83122389,
#    'name': 'curioswitch/curiostack',
#    'url': 'https://api.github.com/repos/curioswitch/curiostack'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/curioswitch/curiostack/issues/509',
#     'repository_url': 'https://api.github.com/repos/curioswitch/curiostack',
#     'labels_url': 'https://api.github.com/repos/curioswitch/curiostack/issues/509/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/curioswitch/curiostack/issues/509/comments',
#     'events_url': 'https://api.github.com/repos/curioswitch/curiostack/issues/509/events',
#     'html_url': 'https://github.com/curioswitch/curiostack/pull/509',
#     'id': 558882381,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzcwMTUzMTIy',
#     'number': 509,
#     'title': 'Add URL to storage exceptions since error responses usually only have…',
#     'user': {'login': 'chokoswitch',
#      'id': 5175532,
#      'node_id': 'MDQ6VXNlcjUxNzU1MzI=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/5175532?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/chokoswitch',
#      'html_url': 'https://github.com/chokoswitch',
#      'followers_url': 'https://api.github.com/users/chokoswitch/followers',
#      'following_url': 'https://api.github.com/users/chokoswitch/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/chokoswitch/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/chokoswitch/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/chokoswitch/subscriptions',
#      'organizations_url': 'https://api.github.com/users/chokoswitch/orgs',
#      'repos_url': 'https://api.github.com/users/chokoswitch/repos',
#      'events_url': 'https://api.github.com/users/chokoswitch/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/chokoswitch/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-02-03T06:57:06Z',
#     'updated_at': '2020-02-03T07:00:52Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/curioswitch/curiostack/pulls/509',
#      'html_url': 'https://github.com/curioswitch/curiostack/pull/509',
#      'diff_url': 'https://github.com/curioswitch/curiostack/pull/509.diff',
#      'patch_url': 'https://github.com/curioswitch/curiostack/pull/509.patch'},
#     'body': "… something generic like 'not found' which require seeing the URL to understand.\r\n\r\n/cc @danada "},
#    'comment': {'url': 'https://api.github.com/repos/curioswitch/curiostack/issues/comments/581267462',
#     'html_url': 'https://github.com/curioswitch/curiostack/pull/509#issuecomment-581267462',
#     'issue_url': 'https://api.github.com/repos/curioswitch/curiostack/issues/509',
#     'id': 581267462,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU4MTI2NzQ2Mg==',
#     'user': {'login': 'danada',
#      'id': 157375,
#      'node_id': 'MDQ6VXNlcjE1NzM3NQ==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/157375?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/danada',
#      'html_url': 'https://github.com/danada',
#      'followers_url': 'https://api.github.com/users/danada/followers',
#      'following_url': 'https://api.github.com/users/danada/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/danada/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/danada/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/danada/subscriptions',
#      'organizations_url': 'https://api.github.com/users/danada/orgs',
#      'repos_url': 'https://api.github.com/users/danada/repos',
#      'events_url': 'https://api.github.com/users/danada/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/danada/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-03T07:00:52Z',
#     'updated_at': '2020-02-03T07:00:52Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Thanks!'}},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z',
#   'org': {'id': 22391134,
#    'login': 'curioswitch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/curioswitch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22391134?'}},
#  {'id': '11419101074',
#   'type': 'CreateEvent',
#   'actor': {'id': 16960717,
#    'login': 'idsqat1',
#    'display_login': 'idsqat1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idsqat1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16960717?'},
#   'repo': {'id': 237904345,
#    'name': 'idsqat1/idsqat4-Slack-1580713241980',
#    'url': 'https://api.github.com/repos/idsqat1/idsqat4-Slack-1580713241980'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Created for toolchain: https://cloud.ibm.com/devops/toolchains/7a84066a-eb7c-4042-bf56-c36aaa8d81da?env_id=ibm%3Ayp%3Aus-south',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101071',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1311760,
#    'login': 'MohammadHabbab',
#    'display_login': 'MohammadHabbab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MohammadHabbab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1311760?'},
#   'repo': {'id': 44598075,
#    'name': 'tradegecko/smaug',
#    'url': 'https://api.github.com/repos/tradegecko/smaug'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/tradegecko/smaug/issues/91',
#     'repository_url': 'https://api.github.com/repos/tradegecko/smaug',
#     'labels_url': 'https://api.github.com/repos/tradegecko/smaug/issues/91/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/tradegecko/smaug/issues/91/comments',
#     'events_url': 'https://api.github.com/repos/tradegecko/smaug/issues/91/events',
#     'html_url': 'https://github.com/tradegecko/smaug/pull/91',
#     'id': 558820847,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzcwMTAzNDg1',
#     'number': 91,
#     'title': '[FEATURE] Expose Variant Composition and Packsize APIs',
#     'user': {'login': 'MohammadHabbab',
#      'id': 1311760,
#      'node_id': 'MDQ6VXNlcjEzMTE3NjA=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1311760?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MohammadHabbab',
#      'html_url': 'https://github.com/MohammadHabbab',
#      'followers_url': 'https://api.github.com/users/MohammadHabbab/followers',
#      'following_url': 'https://api.github.com/users/MohammadHabbab/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MohammadHabbab/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MohammadHabbab/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MohammadHabbab/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MohammadHabbab/orgs',
#      'repos_url': 'https://api.github.com/users/MohammadHabbab/repos',
#      'events_url': 'https://api.github.com/users/MohammadHabbab/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MohammadHabbab/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2020-02-03T03:39:59Z',
#     'updated_at': '2020-02-03T07:00:52Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/tradegecko/smaug/pulls/91',
#      'html_url': 'https://github.com/tradegecko/smaug/pull/91',
#      'diff_url': 'https://github.com/tradegecko/smaug/pull/91.diff',
#      'patch_url': 'https://github.com/tradegecko/smaug/pull/91.patch'},
#     'body': "### Summary\r\nExpose `variants/[:variant_id]/composition` and `variants/[:variant_id]/packsizes` API details to public consumers to fetch the composition details of their bundles and packsizes.\r\n\r\n### Next Best Alternatives:\r\n- We can add `breakdown=true` flag to TradeGecko's variant API to allow a reduced fetch of the variant and its composition/packsize information in one go.\r\n"},
#    'comment': {'url': 'https://api.github.com/repos/tradegecko/smaug/issues/comments/581267461',
#     'html_url': 'https://github.com/tradegecko/smaug/pull/91#issuecomment-581267461',
#     'issue_url': 'https://api.github.com/repos/tradegecko/smaug/issues/91',
#     'id': 581267461,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU4MTI2NzQ2MQ==',
#     'user': {'login': 'MohammadHabbab',
#      'id': 1311760,
#      'node_id': 'MDQ6VXNlcjEzMTE3NjA=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1311760?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MohammadHabbab',
#      'html_url': 'https://github.com/MohammadHabbab',
#      'followers_url': 'https://api.github.com/users/MohammadHabbab/followers',
#      'following_url': 'https://api.github.com/users/MohammadHabbab/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MohammadHabbab/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MohammadHabbab/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MohammadHabbab/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MohammadHabbab/orgs',
#      'repos_url': 'https://api.github.com/users/MohammadHabbab/repos',
#      'events_url': 'https://api.github.com/users/MohammadHabbab/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MohammadHabbab/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-03T07:00:52Z',
#     'updated_at': '2020-02-03T07:00:52Z',
#     'author_association': 'NONE',
#     'body': "Had a conversation with Ezra and Jason. This PR isn't trying to tackle a solution for 3PLs specifically. It's about documenting an API that is needed, as its information can't be fetched from anywhere else at the moment.\r\n\r\nIf we decided to move forward with a 3PL specific API, then exposing this API would be safe to move forward with. If we decide to change it, then we're most likely going to add to it (not subtract from it) which should be still safe to expose, as we won't have to manage deprecation.\r\n\r\nI believe we can reduce the area of exposure to give access to the composition API only (no need to expose packsize API, as composition is the more generic one, and gives info for packsize too)"}},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z',
#   'org': {'id': 1814492,
#    'login': 'tradegecko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tradegecko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1814492?'}},
#  {'id': '11419101063',
#   'type': 'PushEvent',
#   'actor': {'id': 30367862,
#    'login': 'Aaryatech',
#    'display_login': 'Aaryatech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aaryatech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30367862?'},
#   'repo': {'id': 173936588,
#    'name': 'Aaryatech/RUSA_App',
#    'url': 'https://api.github.com/repos/Aaryatech/RUSA_App'},
#   'payload': {'push_id': 4578211805,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '145dd6b871f3dfdc43e4a09b01bab445b63f8c17',
#    'before': 'f58a3bd8c8252600dd787b8db8346203b4ed3dc9',
#    'commits': [{'sha': '145dd6b871f3dfdc43e4a09b01bab445b63f8c17',
#      'author': {'email': 'viplavthoke@gmail.com', 'name': 'Viplav Thoke'},
#      'message': 'Monika',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Aaryatech/RUSA_App/commits/145dd6b871f3dfdc43e4a09b01bab445b63f8c17'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101064',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 159173322,
#    'name': 'xedi/laravel-behat',
#    'url': 'https://api.github.com/repos/xedi/laravel-behat'},
#   'payload': {'action': 'closed',
#    'number': 87,
#    'pull_request': {'url': 'https://api.github.com/repos/xedi/laravel-behat/pulls/87',
#     'id': 369793969,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzY5NzkzOTY5',
#     'html_url': 'https://github.com/xedi/laravel-behat/pull/87',
#     'diff_url': 'https://github.com/xedi/laravel-behat/pull/87.diff',
#     'patch_url': 'https://github.com/xedi/laravel-behat/pull/87.patch',
#     'issue_url': 'https://api.github.com/repos/xedi/laravel-behat/issues/87',
#     'number': 87,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump symfony/dependency-injection from 4.4.3 to 4.4.4',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [symfony/dependency-injection](https://github.com/symfony/dependency-injection) from 4.4.3 to 4.4.4.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/symfony/dependency-injection/commit/ec60a7d12f5e8ab0f99456adce724717d9c1784a"><code>ec60a7d</code></a> [DI] fix CheckTypeDeclarationsPass</li>\n<li><a href="https://github.com/symfony/dependency-injection/commit/cb20e3ce20652ee7083ff085883b3c6f4fb739de"><code>cb20e3c</code></a> [DI]  CheckTypeDeclarationsPass now checks if value is type of parameter type</li>\n<li>See full diff in <a href="https://github.com/symfony/dependency-injection/compare/v4.4.3...v4.4.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=symfony/dependency-injection&package-manager=composer&previous-version=4.4.3&new-version=4.4.4)](https://dependabot.com/compatibility-score.html?dependency-name=symfony/dependency-injection&package-manager=composer&previous-version=4.4.3&new-version=4.4.4)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\nIf all status checks pass Dependabot will automatically merge this pull request.\n\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot badge me` will comment on this PR with code to add a "Dependabot enabled" badge to your readme\n\nAdditionally, you can set the following in the `.dependabot/config.yml` file in this repo:\n- Update frequency\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\n- Out-of-range updates (receive only lockfile updates, if desired)\n- Security updates (receive only security updates, if desired)\n\n\n\n</details>',
#     'created_at': '2020-01-31T22:16:14Z',
#     'updated_at': '2020-02-03T07:00:52Z',
#     'closed_at': '2020-02-03T07:00:51Z',
#     'merged_at': '2020-02-03T07:00:51Z',
#     'merge_commit_sha': 'f61ef2428e96c11def667e41e4356e6c453eb71e',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1652613662,
#       'node_id': 'MDU6TGFiZWwxNjUyNjEzNjYy',
#       'url': 'https://api.github.com/repos/xedi/laravel-behat/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/xedi/laravel-behat/pulls/87/commits',
#     'review_comments_url': 'https://api.github.com/repos/xedi/laravel-behat/pulls/87/comments',
#     'review_comment_url': 'https://api.github.com/repos/xedi/laravel-behat/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/xedi/laravel-behat/issues/87/comments',
#     'statuses_url': 'https://api.github.com/repos/xedi/laravel-behat/statuses/7e9fb4d02228fc5413eb54e4c5b56cc20e823d7f',
#     'head': {'label': 'xedi:dependabot/composer/master/symfony/dependency-injection-4.4.4',
#      'ref': 'dependabot/composer/master/symfony/dependency-injection-4.4.4',
#      'sha': '7e9fb4d02228fc5413eb54e4c5b56cc20e823d7f',
#      'user': {'login': 'xedi',
#       'id': 3727526,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3Mjc1MjY=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/3727526?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/xedi',
#       'html_url': 'https://github.com/xedi',
#       'followers_url': 'https://api.github.com/users/xedi/followers',
#       'following_url': 'https://api.github.com/users/xedi/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/xedi/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/xedi/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/xedi/subscriptions',
#       'organizations_url': 'https://api.github.com/users/xedi/orgs',
#       'repos_url': 'https://api.github.com/users/xedi/repos',
#       'events_url': 'https://api.github.com/users/xedi/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/xedi/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 159173322,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTkxNzMzMjI=',
#       'name': 'laravel-behat',
#       'full_name': 'xedi/laravel-behat',
#       'private': False,
#       'owner': {'login': 'xedi',
#        'id': 3727526,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3Mjc1MjY=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/3727526?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/xedi',
#        'html_url': 'https://github.com/xedi',
#        'followers_url': 'https://api.github.com/users/xedi/followers',
#        'following_url': 'https://api.github.com/users/xedi/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/xedi/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/xedi/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/xedi/subscriptions',
#        'organizations_url': 'https://api.github.com/users/xedi/orgs',
#        'repos_url': 'https://api.github.com/users/xedi/repos',
#        'events_url': 'https://api.github.com/users/xedi/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/xedi/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/xedi/laravel-behat',
#       'description': 'Behat Extension for Laravel and Lumen',
#       'fork': False,
#       'url': 'https://api.github.com/repos/xedi/laravel-behat',
#       'forks_url': 'https://api.github.com/repos/xedi/laravel-behat/forks',
#       'keys_url': 'https://api.github.com/repos/xedi/laravel-behat/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/xedi/laravel-behat/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/xedi/laravel-behat/teams',
#       'hooks_url': 'https://api.github.com/repos/xedi/laravel-behat/hooks',
#       'issue_events_url': 'https://api.github.com/repos/xedi/laravel-behat/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/xedi/laravel-behat/events',
#       'assignees_url': 'https://api.github.com/repos/xedi/laravel-behat/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/xedi/laravel-behat/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/xedi/laravel-behat/tags',
#       'blobs_url': 'https://api.github.com/repos/xedi/laravel-behat/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/xedi/laravel-behat/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/xedi/laravel-behat/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/xedi/laravel-behat/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/xedi/laravel-behat/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/xedi/laravel-behat/languages',
#       'stargazers_url': 'https://api.github.com/repos/xedi/laravel-behat/stargazers',
#       'contributors_url': 'https://api.github.com/repos/xedi/laravel-behat/contributors',
#       'subscribers_url': 'https://api.github.com/repos/xedi/laravel-behat/subscribers',
#       'subscription_url': 'https://api.github.com/repos/xedi/laravel-behat/subscription',
#       'commits_url': 'https://api.github.com/repos/xedi/laravel-behat/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/xedi/laravel-behat/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/xedi/laravel-behat/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/xedi/laravel-behat/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/xedi/laravel-behat/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/xedi/laravel-behat/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/xedi/laravel-behat/merges',
#       'archive_url': 'https://api.github.com/repos/xedi/laravel-behat/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/xedi/laravel-behat/downloads',
#       'issues_url': 'https://api.github.com/repos/xedi/laravel-behat/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/xedi/laravel-behat/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/xedi/laravel-behat/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/xedi/laravel-behat/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/xedi/laravel-behat/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/xedi/laravel-behat/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/xedi/laravel-behat/deployments',
#       'created_at': '2018-11-26T13:23:32Z',
#       'updated_at': '2020-02-03T07:00:37Z',
#       'pushed_at': '2020-02-03T07:00:51Z',
#       'git_url': 'git://github.com/xedi/laravel-behat.git',
#       'ssh_url': 'git@github.com:xedi/laravel-behat.git',
#       'clone_url': 'https://github.com/xedi/laravel-behat.git',
#       'svn_url': 'https://github.com/xedi/laravel-behat',
#       'homepage': 'https://xedi.com',
#       'size': 579,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'xedi:master',
#      'ref': 'master',
#      'sha': '2239cd97a032f0048dfd5fb73ab46a2e701fa48e',
#      'user': {'login': 'xedi',
#       'id': 3727526,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3Mjc1MjY=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/3727526?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/xedi',
#       'html_url': 'https://github.com/xedi',
#       'followers_url': 'https://api.github.com/users/xedi/followers',
#       'following_url': 'https://api.github.com/users/xedi/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/xedi/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/xedi/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/xedi/subscriptions',
#       'organizations_url': 'https://api.github.com/users/xedi/orgs',
#       'repos_url': 'https://api.github.com/users/xedi/repos',
#       'events_url': 'https://api.github.com/users/xedi/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/xedi/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 159173322,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTkxNzMzMjI=',
#       'name': 'laravel-behat',
#       'full_name': 'xedi/laravel-behat',
#       'private': False,
#       'owner': {'login': 'xedi',
#        'id': 3727526,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3Mjc1MjY=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/3727526?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/xedi',
#        'html_url': 'https://github.com/xedi',
#        'followers_url': 'https://api.github.com/users/xedi/followers',
#        'following_url': 'https://api.github.com/users/xedi/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/xedi/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/xedi/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/xedi/subscriptions',
#        'organizations_url': 'https://api.github.com/users/xedi/orgs',
#        'repos_url': 'https://api.github.com/users/xedi/repos',
#        'events_url': 'https://api.github.com/users/xedi/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/xedi/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/xedi/laravel-behat',
#       'description': 'Behat Extension for Laravel and Lumen',
#       'fork': False,
#       'url': 'https://api.github.com/repos/xedi/laravel-behat',
#       'forks_url': 'https://api.github.com/repos/xedi/laravel-behat/forks',
#       'keys_url': 'https://api.github.com/repos/xedi/laravel-behat/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/xedi/laravel-behat/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/xedi/laravel-behat/teams',
#       'hooks_url': 'https://api.github.com/repos/xedi/laravel-behat/hooks',
#       'issue_events_url': 'https://api.github.com/repos/xedi/laravel-behat/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/xedi/laravel-behat/events',
#       'assignees_url': 'https://api.github.com/repos/xedi/laravel-behat/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/xedi/laravel-behat/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/xedi/laravel-behat/tags',
#       'blobs_url': 'https://api.github.com/repos/xedi/laravel-behat/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/xedi/laravel-behat/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/xedi/laravel-behat/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/xedi/laravel-behat/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/xedi/laravel-behat/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/xedi/laravel-behat/languages',
#       'stargazers_url': 'https://api.github.com/repos/xedi/laravel-behat/stargazers',
#       'contributors_url': 'https://api.github.com/repos/xedi/laravel-behat/contributors',
#       'subscribers_url': 'https://api.github.com/repos/xedi/laravel-behat/subscribers',
#       'subscription_url': 'https://api.github.com/repos/xedi/laravel-behat/subscription',
#       'commits_url': 'https://api.github.com/repos/xedi/laravel-behat/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/xedi/laravel-behat/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/xedi/laravel-behat/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/xedi/laravel-behat/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/xedi/laravel-behat/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/xedi/laravel-behat/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/xedi/laravel-behat/merges',
#       'archive_url': 'https://api.github.com/repos/xedi/laravel-behat/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/xedi/laravel-behat/downloads',
#       'issues_url': 'https://api.github.com/repos/xedi/laravel-behat/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/xedi/laravel-behat/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/xedi/laravel-behat/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/xedi/laravel-behat/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/xedi/laravel-behat/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/xedi/laravel-behat/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/xedi/laravel-behat/deployments',
#       'created_at': '2018-11-26T13:23:32Z',
#       'updated_at': '2020-02-03T07:00:37Z',
#       'pushed_at': '2020-02-03T07:00:51Z',
#       'git_url': 'git://github.com/xedi/laravel-behat.git',
#       'ssh_url': 'git@github.com:xedi/laravel-behat.git',
#       'clone_url': 'https://github.com/xedi/laravel-behat.git',
#       'svn_url': 'https://github.com/xedi/laravel-behat',
#       'homepage': 'https://xedi.com',
#       'size': 579,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/xedi/laravel-behat/pulls/87'},
#      'html': {'href': 'https://github.com/xedi/laravel-behat/pull/87'},
#      'issue': {'href': 'https://api.github.com/repos/xedi/laravel-behat/issues/87'},
#      'comments': {'href': 'https://api.github.com/repos/xedi/laravel-behat/issues/87/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/xedi/laravel-behat/pulls/87/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/xedi/laravel-behat/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/xedi/laravel-behat/pulls/87/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/xedi/laravel-behat/statuses/7e9fb4d02228fc5413eb54e4c5b56cc20e823d7f'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 5,
#     'deletions': 5,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z',
#   'org': {'id': 3727526,
#    'login': 'xedi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/xedi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3727526?'}},
#  {'id': '11419101058',
#   'type': 'PushEvent',
#   'actor': {'id': 5080310,
#    'login': 'devanshdalal',
#    'display_login': 'devanshdalal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/devanshdalal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5080310?'},
#   'repo': {'id': 230380884,
#    'name': 'devanshdalal/Projects-TODO',
#    'url': 'https://api.github.com/repos/devanshdalal/Projects-TODO'},
#   'payload': {'push_id': 4578211803,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dab8280fcf782363503eded01c12cff97e4e1243',
#    'before': '54f5571bb4639a0c8ec71e249e5e3d3fe665c750',
#    'commits': [{'sha': 'dab8280fcf782363503eded01c12cff97e4e1243',
#      'author': {'email': 'devanshdalal@users.noreply.github.com',
#       'name': 'Devansh D'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/devanshdalal/Projects-TODO/commits/dab8280fcf782363503eded01c12cff97e4e1243'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101062',
#   'type': 'CreateEvent',
#   'actor': {'id': 30405568,
#    'login': 'kanchwala-yusuf',
#    'display_login': 'kanchwala-yusuf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kanchwala-yusuf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30405568?'},
#   'repo': {'id': 220399288,
#    'name': 'kanchwala-yusuf/odo',
#    'url': 'https://api.github.com/repos/kanchwala-yusuf/odo'},
#   'payload': {'ref': 'experimental-flag',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'OpenShift Do - Fast, iterative OpenShift development',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101056',
#   'type': 'CreateEvent',
#   'actor': {'id': 17022453,
#    'login': 'Gold-yuan',
#    'display_login': 'Gold-yuan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gold-yuan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17022453?'},
#   'repo': {'id': 237904358,
#    'name': 'Gold-yuan/taifu-utils',
#    'url': 'https://api.github.com/repos/Gold-yuan/taifu-utils'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101046',
#   'type': 'PushEvent',
#   'actor': {'id': 10088628,
#    'login': 'SimonWoodburyForget',
#    'display_login': 'SimonWoodburyForget',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SimonWoodburyForget',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10088628?'},
#   'repo': {'id': 220783743,
#    'name': 'SimonWoodburyForget/mindustry-mods',
#    'url': 'https://api.github.com/repos/SimonWoodburyForget/mindustry-mods'},
#   'payload': {'push_id': 4578211800,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '88066a43ba4c5ce690c78dca7aa44dc96a364f5c',
#    'before': '1247477f9116960e9da38c60f71589c4476711fa',
#    'commits': [{'sha': '88066a43ba4c5ce690c78dca7aa44dc96a364f5c',
#      'author': {'email': 'noreply@fakemail.com', 'name': 'bot'},
#      'message': 'Updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SimonWoodburyForget/mindustry-mods/commits/88066a43ba4c5ce690c78dca7aa44dc96a364f5c'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101044',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 48633701,
#    'login': 'pull-assistant[bot]',
#    'display_login': 'pull-assistant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull-assistant[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48633701?'},
#   'repo': {'id': 186574606,
#    'name': 'egovernments/ukd-mdms-data',
#    'url': 'https://api.github.com/repos/egovernments/ukd-mdms-data'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/egovernments/ukd-mdms-data/issues/256',
#     'repository_url': 'https://api.github.com/repos/egovernments/ukd-mdms-data',
#     'labels_url': 'https://api.github.com/repos/egovernments/ukd-mdms-data/issues/256/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/egovernments/ukd-mdms-data/issues/256/comments',
#     'events_url': 'https://api.github.com/repos/egovernments/ukd-mdms-data/issues/256/events',
#     'html_url': 'https://github.com/egovernments/ukd-mdms-data/pull/256',
#     'id': 558883760,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzcwMTU0Mjc4',
#     'number': 256,
#     'title': 'Removing Duplicated',
#     'user': {'login': 'priyankarani-eGov',
#      'id': 19485753,
#      'node_id': 'MDQ6VXNlcjE5NDg1NzUz',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/19485753?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/priyankarani-eGov',
#      'html_url': 'https://github.com/priyankarani-eGov',
#      'followers_url': 'https://api.github.com/users/priyankarani-eGov/followers',
#      'following_url': 'https://api.github.com/users/priyankarani-eGov/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/priyankarani-eGov/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/priyankarani-eGov/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/priyankarani-eGov/subscriptions',
#      'organizations_url': 'https://api.github.com/users/priyankarani-eGov/orgs',
#      'repos_url': 'https://api.github.com/users/priyankarani-eGov/repos',
#      'events_url': 'https://api.github.com/users/priyankarani-eGov/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/priyankarani-eGov/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-02-03T07:00:50Z',
#     'updated_at': '2020-02-03T07:00:52Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/egovernments/ukd-mdms-data/pulls/256',
#      'html_url': 'https://github.com/egovernments/ukd-mdms-data/pull/256',
#      'diff_url': 'https://github.com/egovernments/ukd-mdms-data/pull/256.diff',
#      'patch_url': 'https://github.com/egovernments/ukd-mdms-data/pull/256.patch'},
#     'body': ''},
#    'comment': {'url': 'https://api.github.com/repos/egovernments/ukd-mdms-data/issues/comments/581267460',
#     'html_url': 'https://github.com/egovernments/ukd-mdms-data/pull/256#issuecomment-581267460',
#     'issue_url': 'https://api.github.com/repos/egovernments/ukd-mdms-data/issues/256',
#     'id': 581267460,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU4MTI2NzQ2MA==',
#     'user': {'login': 'pull-assistant[bot]',
#      'id': 48633701,
#      'node_id': 'MDM6Qm90NDg2MzM3MDE=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/27100?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull-assistant%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull-assistant',
#      'followers_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull-assistant%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-02-03T07:00:51Z',
#     'updated_at': '2020-02-03T07:00:51Z',
#     'author_association': 'NONE',
#     'body': '\n<img align="right" src="https://pullassistant.com/assets/score10.svg" alt="Score: 1.00"/>\n\nBest reviewed:  **commit by commit** \n___\n<details>\n<summary>\nOptimal code review plan \n<br/>\n<br/>\n</summary>\n   \n    \n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="https://github.com/egovernments/ukd-mdms-data/pull/256/commits/1b3335628d2ad321f98f984ec9d1d475b2faa09f">Removing Duplicated</a>\n   \n   \n</details>\n\n> Powered by [Pull Assistant](https://pullassistant.com). Last update [1b33356](https://github.com/egovernments/ukd-mdms-data/commit/1b3335628d2ad321f98f984ec9d1d475b2faa09f) ... [1b33356](https://github.com/egovernments/ukd-mdms-data/commit/1b3335628d2ad321f98f984ec9d1d475b2faa09f). Read the [comment docs](https://pullassistant.com).\n'}},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z',
#   'org': {'id': 6940476,
#    'login': 'egovernments',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/egovernments',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6940476?'}},
#  {'id': '11419101048',
#   'type': 'WatchEvent',
#   'actor': {'id': 37320720,
#    'login': 'eecsdanny',
#    'display_login': 'eecsdanny',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eecsdanny',
# ...
#     'labels_url': 'https://api.github.com/repos/hailin-du/michaeltroger.github.io/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/hailin-du/michaeltroger.github.io/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/hailin-du/michaeltroger.github.io/deployments',
#     'created_at': '2020-02-03T07:00:51Z',
#     'updated_at': '2019-07-28T01:21:48Z',
#     'pushed_at': '2017-08-18T07:13:45Z',
#     'git_url': 'git://github.com/hailin-du/michaeltroger.github.io.git',
#     'ssh_url': 'git@github.com:hailin-du/michaeltroger.github.io.git',
#     'clone_url': 'https://github.com/hailin-du/michaeltroger.github.io.git',
#     'svn_url': 'https://github.com/hailin-du/michaeltroger.github.io',
#     'homepage': 'https://michaeltroger.github.io',
#     'size': 3353,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101023',
#   'type': 'PushEvent',
#   'actor': {'id': 45889977,
#    'login': 'bwan910',
#    'display_login': 'bwan910',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bwan910',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45889977?'},
#   'repo': {'id': 237899856,
#    'name': 'bwan910/Email-GUI-',
#    'url': 'https://api.github.com/repos/bwan910/Email-GUI-'},
#   'payload': {'push_id': 4578211783,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e180b6e4c34dc4b7ccab6dbb36399016a51240d7',
#    'before': 'f656cdcb54c1f73acef169de4b9740c0972dead5',
#    'commits': [{'sha': 'e180b6e4c34dc4b7ccab6dbb36399016a51240d7',
#      'author': {'email': 'bwan910@gmail.com', 'name': 'Brandon Wan'},
#      'message': 'Delete application.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bwan910/Email-GUI-/commits/e180b6e4c34dc4b7ccab6dbb36399016a51240d7'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101026',
#   'type': 'CreateEvent',
#   'actor': {'id': 54635114,
#    'login': 'gkswn911',
#    'display_login': 'gkswn911',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gkswn911',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54635114?'},
#   'repo': {'id': 237904353,
#    'name': 'gkswn911/jobtube',
#    'url': 'https://api.github.com/repos/gkswn911/jobtube'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101024',
#   'type': 'CreateEvent',
#   'actor': {'id': 817365,
#    'login': 'erral',
#    'display_login': 'erral',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/erral',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/817365?'},
#   'repo': {'id': 62810750,
#    'name': 'erral/eitbapi',
#    'url': 'https://api.github.com/repos/erral/eitbapi'},
#   'payload': {'ref': 'create-pull-request-1580713201',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Demo app to expose a public API for EITB Nahieran. Featuring this EuroPython 2016 talk: https://ep2016.europython.eu/conference/talks/eitb-nahieran-askatu-bideoak-api-honen-bidez',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101019',
#   'type': 'PushEvent',
#   'actor': {'id': 48097671,
#    'login': 'EmilAndreasyan',
#    'display_login': 'EmilAndreasyan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EmilAndreasyan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48097671?'},
#   'repo': {'id': 237894732,
#    'name': 'EmilAndreasyan/rails-cru-form_for-lab-online-web-pt-090919',
#    'url': 'https://api.github.com/repos/EmilAndreasyan/rails-cru-form_for-lab-online-web-pt-090919'},
#   'payload': {'push_id': 4578211780,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '969eacbea2ae6d9001a5762e4a0a0eb7417c2a4f',
#    'before': '6a7f88dc78ec4245258576c51b324ab7f4f92976',
#    'commits': [{'sha': '969eacbea2ae6d9001a5762e4a0a0eb7417c2a4f',
#      'author': {'email': 'emil.andreasyan@yahoo.com',
#       'name': 'Emil Andreasyan'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EmilAndreasyan/rails-cru-form_for-lab-online-web-pt-090919/commits/969eacbea2ae6d9001a5762e4a0a0eb7417c2a4f'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:51Z'},
#  {'id': '11419101022',
#   'type': 'WatchEvent',
#   'actor': {'id': 60498153,
#    'login': 'vinodnx',
#    'display_login': 'vinodnx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vinodnx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60498153?'},
#   'repo': {'id': 237363838,
#    'name': 'vinodnx/Howie_Smart_Blind',
#    'url': 'https://api.github.com/repos/vinodnx/Howie_Smart_Blind'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:52Z'},
#  {'id': '11419101018',
#   'type': 'ForkEvent',
#   'actor': {'id': 59272966,
#    'login': 'malacandon',
#    'display_login': 'malacandon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/malacandon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59272966?'},
#   'repo': {'id': 37268085,
#    'name': 'priviere/PPBstats',
#    'url': 'https://api.github.com/repos/priviere/PPBstats'},
#   'payload': {'forkee': {'id': 237904357,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzc5MDQzNTc=',
#     'name': 'PPBstats',
#     'full_name': 'malacandon/PPBstats',
#     'private': False,
#     'owner': {'login': 'malacandon',
#      'id': 59272966,
#      'node_id': 'MDQ6VXNlcjU5MjcyOTY2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/59272966?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/malacandon',
#      'html_url': 'https://github.com/malacandon',
#      'followers_url': 'https://api.github.com/users/malacandon/followers',
#      'following_url': 'https://api.github.com/users/malacandon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/malacandon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/malacandon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/malacandon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/malacandon/orgs',
#      'repos_url': 'https://api.github.com/users/malacandon/repos',
#      'events_url': 'https://api.github.com/users/malacandon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/malacandon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/malacandon/PPBstats',
#     'description': 'A R package for Participatory Plant Breeding statisticial analyses',
#     'fork': True,
#     'url': 'https://api.github.com/repos/malacandon/PPBstats',
#     'forks_url': 'https://api.github.com/repos/malacandon/PPBstats/forks',
#     'keys_url': 'https://api.github.com/repos/malacandon/PPBstats/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/malacandon/PPBstats/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/malacandon/PPBstats/teams',
#     'hooks_url': 'https://api.github.com/repos/malacandon/PPBstats/hooks',
#     'issue_events_url': 'https://api.github.com/repos/malacandon/PPBstats/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/malacandon/PPBstats/events',
#     'assignees_url': 'https://api.github.com/repos/malacandon/PPBstats/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/malacandon/PPBstats/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/malacandon/PPBstats/tags',
#     'blobs_url': 'https://api.github.com/repos/malacandon/PPBstats/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/malacandon/PPBstats/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/malacandon/PPBstats/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/malacandon/PPBstats/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/malacandon/PPBstats/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/malacandon/PPBstats/languages',
#     'stargazers_url': 'https://api.github.com/repos/malacandon/PPBstats/stargazers',
#     'contributors_url': 'https://api.github.com/repos/malacandon/PPBstats/contributors',
#     'subscribers_url': 'https://api.github.com/repos/malacandon/PPBstats/subscribers',
#     'subscription_url': 'https://api.github.com/repos/malacandon/PPBstats/subscription',
#     'commits_url': 'https://api.github.com/repos/malacandon/PPBstats/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/malacandon/PPBstats/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/malacandon/PPBstats/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/malacandon/PPBstats/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/malacandon/PPBstats/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/malacandon/PPBstats/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/malacandon/PPBstats/merges',
#     'archive_url': 'https://api.github.com/repos/malacandon/PPBstats/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/malacandon/PPBstats/downloads',
#     'issues_url': 'https://api.github.com/repos/malacandon/PPBstats/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/malacandon/PPBstats/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/malacandon/PPBstats/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/malacandon/PPBstats/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/malacandon/PPBstats/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/malacandon/PPBstats/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/malacandon/PPBstats/deployments',
#     'created_at': '2020-02-03T07:00:51Z',
#     'updated_at': '2020-01-07T07:21:50Z',
#     'pushed_at': '2019-09-09T13:01:07Z',
#     'git_url': 'git://github.com/malacandon/PPBstats.git',
#     'ssh_url': 'git@github.com:malacandon/PPBstats.git',
#     'clone_url': 'https://github.com/malacandon/PPBstats.git',
#     'svn_url': 'https://github.com/malacandon/PPBstats',
#     'homepage': 'https://priviere.github.io/PPBstats_web_site/',
#     'size': 33461,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-02-03T07:00:51Z'},
#  {'id': '11419101013',
#   'type': 'PushEvent',
#   'actor': {'id': 43452376,
#    'login': 'geovanicv',
#    'display_login': 'geovanicv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/geovanicv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43452376?'},
#   'repo': {'id': 237896258,
#    'name': 'geovanicv/fastFeet',
#    'url': 'https://api.github.com/repos/geovanicv/fastFeet'},
#   'payload': {'push_id': 4578211775,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '564e2f735477a4a1b8655fee60a35b69020f97c9',
#    'before': '16ddc888b7558e3c48f4613419aff7981aca3c7c',
#    'commits': [{'sha': '564e2f735477a4a1b8655fee60a35b69020f97c9',
#      'author': {'email': 'geovani.scavalcante@gmail.com',
#       'name': 'Geovani Cavalcante'},
#      'message': 'Configurando sequelize e criando migrate de user',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/geovanicv/fastFeet/commits/564e2f735477a4a1b8655fee60a35b69020f97c9'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:51Z'},
#  {'id': '11419101016',
#   'type': 'CreateEvent',
#   'actor': {'id': 50486669,
#    'login': 'steviebramante',
#    'display_login': 'steviebramante',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/steviebramante',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50486669?'},
#   'repo': {'id': 237904355,
#    'name': 'steviebramante/meelohchi',
#    'url': 'https://api.github.com/repos/steviebramante/meelohchi'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:51Z'},
#  {'id': '11419101014',
#   'type': 'CreateEvent',
#   'actor': {'id': 16960717,
#    'login': 'idsqat1',
#    'display_login': 'idsqat1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idsqat1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16960717?'},
#   'repo': {'id': 237904343,
#    'name': 'idsqat1/idsqat4-PagerDuty-1580713240782',
#    'url': 'https://api.github.com/repos/idsqat1/idsqat4-PagerDuty-1580713240782'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-03T07:00:51Z'},
#  {'id': '11419101002',
#   'type': 'PushEvent',
#   'actor': {'id': 55035084,
#    'login': 'afuadeborah',
#    'display_login': 'afuadeborah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/afuadeborah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55035084?'},
#   'repo': {'id': 237343382,
#    'name': 'afuadeborah/afua-frimpong-project-two',
#    'url': 'https://api.github.com/repos/afuadeborah/afua-frimpong-project-two'},
#   'payload': {'push_id': 4578211769,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c71273833681785b3135ff0d00752c9899206c24',
#    'before': '983b7290843ed66682c67fa77dd2de70d8c561a1',
#    'commits': [{'sha': 'c71273833681785b3135ff0d00752c9899206c24',
#      'author': {'email': 'afrimpong.15@gmail.com', 'name': 'Afua Frimpong'},
#      'message': 'Indentation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/afuadeborah/afua-frimpong-project-two/commits/c71273833681785b3135ff0d00752c9899206c24'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:51Z'},
#  {'id': '11419100993',
#   'type': 'PushEvent',
#   'actor': {'id': 14127285,
#    'login': 'funilrys',
#    'display_login': 'funilrys',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/funilrys',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14127285?'},
#   'repo': {'id': 124744454,
#    'name': 'Ultimate-Hosts-Blacklist/Ads_Disconnect.me',
#    'url': 'https://api.github.com/repos/Ultimate-Hosts-Blacklist/Ads_Disconnect.me'},
#   'payload': {'push_id': 4578211765,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd39704043467a1c6a45c549f59b2d242184ae9ae',
#    'before': '2646c2f797737962c626babfa571e69ef0d080a2',
#    'commits': [{'sha': 'd39704043467a1c6a45c549f59b2d242184ae9ae',
#      'author': {'email': 'contact@funilrys.com', 'name': 'Nissar Chababy'},
#      'message': '[MON] [Restart last part]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ultimate-Hosts-Blacklist/Ads_Disconnect.me/commits/d39704043467a1c6a45c549f59b2d242184ae9ae'}]},
#   'public': True,
#   'created_at': '2020-02-03T07:00:51Z',
#   'org': {'id': 37181187,
#    'login': 'Ultimate-Hosts-Blacklist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Ultimate-Hosts-Blacklist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37181187?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json
r=requests.get('https://cat-fact.herokuapp.com/facts', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'type': 'cat',
#    'text': 'Cats see only on blue and yellow.',
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'type': 'cat',
#    'text': 'Cats are dumb.',
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'type': 'cat',
#    'text': 'Cat.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'type': 'cat',
#    'text': 'Sleep.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'type': 'cat',
#    'text': 'Cat is an animal.',
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'type': 'cat',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'type': 'cat',
#    'text': 'Hi.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'type': 'cat',
#    'text': '123.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'type': 'cat',
#    'text': 'Fgf.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e353507cd8efb0015ae305d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
